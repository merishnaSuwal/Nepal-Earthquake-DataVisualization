# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import rcParams

# %%
# %matplotlib inline

# %%
import seaborn as sns

# %% [markdown]
# ## Import data from csv

# %%
data_input = pd.read_csv('Causalities caused by earthquake,2015.csv')

# %%
data_input.head()
# Out:
#         District     Zone Geographical Region Development Region  \
# 0  Sindhupalchok  Bagmati            Mountain            Central
# 1  Sindhupalchok  Bagmati            Mountain            Central
# 2  Sindhupalchok  Bagmati            Mountain            Central
# 3  Sindhupalchok  Bagmati            Mountain            Central
# 4  Sindhupalchok  Bagmati            Mountain            Central
#
#            Causalities  In Number
# 0  Total No. of Houses      66688
# 1     Total Population     287798
# 2            Dead Male       1497
# 3          Dead Female       1943
# 4         Dead Unknown          0

# %%
data_input['Causalities'].unique()
# Out:
# array(['Total No. of Houses', 'Total Population', 'Dead Male',
#        'Dead Female', 'Dead Unknown', 'Injured',
#        'Govt. Houses Fully Destroyed', 'Govt. Houses Partially Destroyed',
#        'Public House Fully Destroyed', 'Public House Partially Destroyed'],
#       dtype=object)

# %%
data_input['District'].unique()
# Out:
# array(['Sindhupalchok', 'Kathmandu', 'Nuwakot', 'Dhading', 'Rasuwa',
#        'Gorkha', 'Bhaktapur', 'Kavre', 'Lalitpur', 'Dolakha', 'Ramechhap',
#        'Makwanpur', 'Solukhumbu', 'Okhaldhunga', 'Sindhuli', 'Chitawan',
#        'Sunsari', 'Parsa', 'Bara', 'Lamjung', 'Mahottari', 'Rautahat',
#        'Kaski', 'Morang', 'Bhojpur', 'Sarlahi', 'Taplejung', 'Jhapa',
#        'Terhathum', 'Udayapur', 'Siraha', 'Dhanusa', 'Nawalparasi',
#        'Palpa', 'Gulmi', 'Baglung', 'Rolpa', 'Rukum', 'Panchthar', 'Ilam',
#        'Dhankuta', 'Sankhuwasabha', 'Khotang', 'Saptari', 'Rupandehi',
#        'Kapilbastu', 'Arghakhanchi', 'Syangja', 'Tanahu', 'Manang',
#        'Mustang', 'Myagdi', 'Parbat', 'Dang', 'Pyuthan', 'Salyan',
#        'Dolpa', 'Mugu', 'Humla', 'Jumla', 'Kalikot', 'Jajarkot',
#        'Dailekh', 'Surkhet', 'Bardiya', 'Banke', 'Kailali', 'Doti',
#        'Achham', 'Bajura', 'Bajhang', 'Darchaula', 'Baitadi',
#        'Dadeldhura', 'Kanchanpur'], dtype=object)

# %%
# data_input.drop()

# %%
data_input.columns
# Out:
# Index(['District', 'Zone', 'Geographical Region', 'Development Region',
#        'Causalities', 'In Number'],
#       dtype='object')

# %%
data_input.head()
# Out:
#         District     Zone Geographical Region Development Region  \
# 0  Sindhupalchok  Bagmati            Mountain            Central
# 1  Sindhupalchok  Bagmati            Mountain            Central
# 2  Sindhupalchok  Bagmati            Mountain            Central
# 3  Sindhupalchok  Bagmati            Mountain            Central
# 4  Sindhupalchok  Bagmati            Mountain            Central
#
#            Causalities  In Number
# 0  Total No. of Houses      66688
# 1     Total Population     287798
# 2            Dead Male       1497
# 3          Dead Female       1943
# 4         Dead Unknown          0

# %% [markdown]
# ## Get only injured person data

# %%
viz_injured_data = data_input[data_input['Causalities']== 'Injured']

# %%
viz_injured_data.head()
# Out:
#          District     Zone Geographical Region Development Region Causalities  \
# 5   Sindhupalchok  Bagmati            Mountain            Central     Injured
# 15      Kathmandu  Bagmati                Hill            Central     Injured
# 25        Nuwakot  Bagmati                Hill            Central     Injured
# 35        Dhading  Bagmati                Hill            Central     Injured
# 45         Rasuwa  Bagmati            Mountain            Central     Injured
#
#     In Number
# 5        1571
# 15       7859
# 25       1052
# 35       1218
# 45        771

# %% [markdown]
# ## Get the data for no. of persons injured for Bagmati Zone

# %%
viz_zone = data_input[data_input['Zone']=='Bagmati']

# %% [markdown]
# ### Visualize the data [Number of persons injured, Districts]

# %%
# viz_injured_data.plot(x='District', y='In Number', kind='bar')
plt.figure(figsize = (28,10))
plt.title('Number of persons injured in Bagmati zone',fontsize=25)
sns.set_context('poster',font_scale=1.5,rc={"lines.linewidth": 2})
sns_plot = sns.barplot(x='District',y='In Number',data=viz_zone,ci=None)
plt.ylim(0,300000)

# Create names
# plt.xticks(y_pos, bars)
plt.xlabel('Districts',fontsize=25)
plt.ylabel('Injured people',fontsize=25)
plt.tight_layout()

# %%
viz_death_data1 = data_input[data_input['Causalities']== 'Dead Male']

# %%
viz_death_data1.head()
# Out:
#          District     Zone Geographical Region Development Region Causalities  \
# 2   Sindhupalchok  Bagmati            Mountain            Central   Dead Male
# 12      Kathmandu  Bagmati                Hill            Central   Dead Male
# 22        Nuwakot  Bagmati                Hill            Central   Dead Male
# 32        Dhading  Bagmati                Hill            Central   Dead Male
# 42         Rasuwa  Bagmati            Mountain            Central   Dead Male
#
#     In Number
# 2        1497
# 12        621
# 22        456
# 32        340
# 42        287

# %% [markdown]
# ## Visualizing data for zones in Central Development region

# %%
viz_devregion = data_input[data_input['Development Region']=='Central']

# %%
viz_devregion['Zone'].unique()
# Out:
# array(['Bagmati', 'Janakpur', 'Narayani'], dtype=object)

# %%
g = sns.factorplot(x="District", y="In Number",
                    col="Zone",ci= None,col_wrap=4,
                   data=viz_devregion, kind="bar",
                   size=9, aspect=1);
g.set_axis_labels("Districts", "Number of people injured")
g.set(ylim=(0, 200000))
g.set_titles("{col_name} {col_var}")
# plt.title('Number of people injured zone-wise due to 2015 earthquake')
